# %% [markdown]
# ## Setting the environment

# %% [markdown]
# To calculate over the dataset we used Python environment containing Numpy and Pandas.

# %%
import matplotlib.pyplot as plt
plt.style.use('classic')
# %matplotlib inline
import numpy as np
import pandas as pd
import seaborn as sns
sns.set()

# %% [markdown]
# ## Input

# %%
df1 = pd.read_csv("13_12-0.csv")

# %%
df1.head(5)
# Out:
#    asset_id  followers  engagement  day_of_week  hour_of_day  current_views  \
# 0  19779063    3617754         0.2            4           18          17898
# 1  19591453     103910         2.0            1           18              0
# 2  18959298     315266         7.3            0           18              0
# 3  18907487     710855         1.0            0           18              0
# 4  19833665     617056         0.1            4           18           1679
#
#    current_minute  current_comments  current_reactions   platform asset_type  \
# 0           18887                29               2988  instagram    Episode
# 1           23208                85               4171  instagram      Image
# 2           34727               127              29185  instagram      Image
# 3           34728                17               3457  instagram      Image
# 4           18887                 3                 52  instagram    Episode
#
# ...

# %%
df1.shape
# Out:
# (11670920, 17)

# %%
df1 = df1.drop(columns = ['next_minute' ,'next_reactions', 'next_comments', 'next_views'])

# %%
df1['asset_id'].nunique()
# Out:
# 2486958

# %% [markdown]
# Drop duplicated asset_id

# %%
df_nd = df1.drop_duplicates(subset = ['asset_id'])

# %%
df_nd.shape
# Out:
# (2486958, 13)

# %% [markdown]
# ## Feature selection

# %%
df_nd = df_nd.drop(columns = ['asset_type', 'platform'])

# %%
from sklearn import model_selection
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.tree import DecisionTreeClassifier

from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection chi2

# %%
print(df_nd.dtypes)
# Out:
# asset_id               int64
# followers              int64
# engagement           float64
# day_of_week            int64
# hour_of_day            int64
# current_views          int64
# current_minute         int64
# current_comments       int64
# current_reactions      int64
# has_sponsor             bool
# category_number        int64
# dtype: object

# %% [markdown]
# ## Correlations

# %% [markdown]
# The heatmap describes the correlation between variables. Reactions, views and comments slightly relate to each other. The rest of the variables looks informative. Nothing is to be dropped, and even more variables can be added to the dataset to bring more information.

# %%
sns.heatmap(df_nd.corr(), annot=True)
plt.show()
